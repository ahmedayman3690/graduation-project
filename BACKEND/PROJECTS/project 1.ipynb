# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\MOKIJ\Desktop\project_1\chicago.csv')

# %%
pd.DataFrame(df)
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1           955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2             9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3           304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4            45207 2017-01-17 14:53:07  2017-01-17 15:02:01            534
# ...            ...                 ...                  ...            ...
# 299995       64825 2017-01-21 13:18:00  2017-01-21 13:27:50            590
# 299996      695993 2017-04-28 19:32:19  2017-04-28 19:51:18           1139
# 299997      159685 2017-02-12 09:59:01  2017-02-12 10:21:49           1368
# 299998      564681 2017-04-16 17:07:15  2017-04-16 17:19:00            705
# 299999     1021247 2017-05-30 12:38:28  2017-05-30 12:55:36           1028
#
# ...

# %%
df['Start Time'] = pd.to_datetime(df['Start Time'])

# %%
df['hour'] = df['Start Time'].dt.hour

# %%
print('the comon time is:',df['hour'].mode()[0],df['hour'].value_counts())
# Out:
# the comon time is: 17 17    0.119973
# 16    0.095807
# 8     0.080447
# 18    0.078373
# 15    0.067027
# 7     0.061267
# 14    0.058653
# 13    0.058530
# 12    0.058223
# 19    0.052383
# 11    0.050133
# 9     0.045637
# 10    0.039840
# 20    0.034337
# 6     0.027487
# 21    0.023677
# 22    0.016317
# 23    0.010047
# 5     0.008123
# 0     0.005620
# 1     0.003273
# 2     0.002030
# 4     0.001557
# 3     0.001240
# Name: hour, dtype: float64

# %%
print('the commen hour is {} and it repeated in the data for {}'.format(df['hour'].mode()[0], df['hour'].value_counts()[df['hour'].mode()[0]]))
# Out:
# the commen hour is 17 and it repeated in the data for 35992

# %%
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year',
#        'hour'],
#       dtype='object')

# %%
df['month'] = df['Start Time'].dt.month

# %%
df['day_of_week'] = df['Start Time'].dt.weekday

# %%
pd.DataFrame(df)
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1           955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2             9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3           304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4            45207 2017-01-17 14:53:07  2017-01-17 15:02:01            534
# ...            ...                 ...                  ...            ...
# 299995       64825 2017-01-21 13:18:00  2017-01-21 13:27:50            590
# 299996      695993 2017-04-28 19:32:19  2017-04-28 19:51:18           1139
# 299997      159685 2017-02-12 09:59:01  2017-02-12 10:21:49           1368
# 299998      564681 2017-04-16 17:07:15  2017-04-16 17:19:00            705
# 299999     1021247 2017-05-30 12:38:28  2017-05-30 12:55:36           1028
#
# ...

# %%
months = ['january', 'february', 'march', 'april', 'may', 'june']

# %%
month=input('enter the month:')
if month != 'all':
    month= months[month]
# Out:
# enter the month:all
